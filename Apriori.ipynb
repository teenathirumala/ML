# %% [markdown]
# Association  rule learning:
# Apriori:people who bought this also bought that....

# %% [markdown]
# # Apriori

# %% [markdown]
# scikit learn doesnt have apriori functions so we use other library

# %%
# !pip install Apyori
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for Apyori: filename=apyori-1.1.2-py3-none-any.whl size=5955 sha256=10e250fe82281f8f11d9e7c0fa7aee5da589f190cf5f7ec4c07bbc779f22c394
#   Stored in directory: /root/.cache/pip/wheels/c4/1a/79/20f55c470a50bb3702a8cb7c94d8ada15573538c7f4baebe2d
# Successfully built Apyori
# ...

# %% [markdown]
# **importing libraries**

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# **Data preproessing**

# %%
dataset = pd.read_csv('Market_Basket_Optimisation.csv', header = None)
transactions=[]
for i in range(0,7501):
  transactions.append([str(dataset.values[i,j]) for j in range (0,20)])

# %% [markdown]
# **Training the apriori model on the dataset**

# %% [markdown]
# min support=3*7/7501
# ,min confidence=

# %%
from apyori import apriori
rules=apriori(transactions=transactions,min_support=0.003,min_confidence=0.2,min_lift=3,min_length=2,max_length=2)

# %% [markdown]
# **Visualising results**

# %% [markdown]
# **Displaying the first results coming from the output of the apriori function**

# %%
results=list(rules)
results
# Out:
# [RelationRecord(items=frozenset({'light cream', 'chicken'}), support=0.004532728969470737, ordered_statistics=[OrderedStatistic(items_base=frozenset({'light cream'}), items_add=frozenset({'chicken'}), confidence=0.29059829059829057, lift=4.84395061728395)]),
#  RelationRecord(items=frozenset({'mushroom cream sauce', 'escalope'}), support=0.005732568990801226, ordered_statistics=[OrderedStatistic(items_base=frozenset({'mushroom cream sauce'}), items_add=frozenset({'escalope'}), confidence=0.3006993006993007, lift=3.790832696715049)]),
#  RelationRecord(items=frozenset({'escalope', 'pasta'}), support=0.005865884548726837, ordered_statistics=[OrderedStatistic(items_base=frozenset({'pasta'}), items_add=frozenset({'escalope'}), confidence=0.3728813559322034, lift=4.700811850163794)]),
# ...

# %% [markdown]
# **Putting the results well organised into a Pandas dataframe**

# %%
def inspect(results):
  lhs=[tuple(result[2][0][0])[0] for result in results]
  rhs=[tuple(result[2][0][1])[0] for result in results]
  supports=[result[1] for result in results]
  confidences=[result[2][0][2] for result in results]
  lifts=[result[2][0][3] for result in results]
  return list(zip(lhs,rhs,supports,confidences,lifts))

resultsinDataFrame=pd.DataFrame(inspect(results),columns=['Left Hand Side','Right Hand Side','Support','Confidence','Lift'])

# %% [markdown]
# **Display the results non sorted**

# %%
resultsinDataFrame
# Out:
#            Left Hand Side Right Hand Side   Support  Confidence      Lift
# 0             light cream         chicken  0.004533    0.290598  4.843951
# 1    mushroom cream sauce        escalope  0.005733    0.300699  3.790833
# 2                   pasta        escalope  0.005866    0.372881  4.700812
# 3           fromage blanc           honey  0.003333    0.245098  5.164271
# 4           herb & pepper     ground beef  0.015998    0.323450  3.291994
# ..                    ...             ...       ...         ...       ...
# 155           ground beef   mineral water  0.003066    0.216981  3.632981
# 156           ground beef   mineral water  0.003066    0.211009  3.532991
# 157           ground beef   mineral water  0.003066    0.261364  4.376091
# 158                  milk             nan  0.003333    0.211864  3.223519
# 159                  milk   mineral water  0.003333    0.238095  3.986501
#
# [160 rows x 5 columns]

# %% [markdown]
# **Displaying the results sorted by  descending lifts**

# %%
resultsinDataFrame.nlargest(n=10,columns='Lift')
# Out:
#         Left Hand Side Right Hand Side   Support  Confidence      Lift
# 97   frozen vegetables            milk  0.003066    0.383333  7.987176
# 150  frozen vegetables   mineral water  0.003066    0.383333  7.987176
# 96           olive oil            milk  0.003333    0.294118  6.128268
# 149          olive oil   mineral water  0.003333    0.294118  6.128268
# 132      mineral water             nan  0.003866    0.402778  6.128268
# 59       mineral water       olive oil  0.003866    0.402778  6.115863
# 50        tomato sauce     ground beef  0.003066    0.216981  5.535971
# 122       tomato sauce     ground beef  0.003066    0.216981  5.535971
# 28       fromage blanc             nan  0.003333    0.245098  5.178818
# 3        fromage blanc           honey  0.003333    0.245098  5.164271
